# %% [markdown]
# # Summary Results

# %%
# %matplotlib inline
#%config InlineBackend.figure_format='retina'

from __future__ import absolute_import, division, print_function
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib.pyplot import GridSpec
import seaborn as sns
import numpy as np
import pandas as pd
#import os, sys
#from tqdm import tqdm
import warnings

# %%
# importing the data set
plot_df = pd.read_csv("clean_df.csv")

# %%
plot_df.head(2)
# Out:
#    Unnamed: 0                   user_id device_model               time_stamp  \
# 0           0  59742df346ab8ae80d7320e5     SM-J200G  2017-10-29 05:52:28.059
# 1           1  59d23b4cb2cb0511457c3718     Redmi 4A  2017-10-02 13:16:23.309
#
#    year  month  day  hour cleaned_mobile_name
# 0  2017     10   29     5             Samsung
# 1  2017     10    2    13              Xiaomi

# %%
#housing keeping and rearranging the columns
plot_df = plot_df.iloc[:,[1,8,2,3,4,5,6,7]]

# %%
plot_df = plot_df.rename(index=str, columns={'cleaned_mobile_name': "mobile_brand_name"})

# %%
plot_df.head(2)
# Out:
#                     user_id mobile_brand_name device_model  \
# 0  59742df346ab8ae80d7320e5           Samsung     SM-J200G
# 1  59d23b4cb2cb0511457c3718            Xiaomi     Redmi 4A
#
#                time_stamp  year  month  day  hour
# 0 2017-10-29 05:52:28.059  2017     10   29     5
# 1 2017-10-02 13:16:23.309  2017     10    2    13

# %%
import datetime as dt
plot_df.time_stamp = pd.to_datetime(plot_df.time_stamp)

# %% [markdown]
# ### Visaulization

# %%
plot_df.device_model.values
# Out:
# array(['SM-J200G', 'Redmi 4A', 'Swipe_Elite_3', ..., 'SM-J700F',
#        'vivo Y21L', 'vivo Y51L'], dtype=object)

# %%
# Out:
# <bound method IndexOpsMixin.value_counts of 0              SM-J200G
# 1              Redmi 4A
# 2         Swipe_Elite_3
# 3                  A37f
# 4                 C6902
# 5              SM-J700F
# 6             OctaOne_5
# 7          Redmi Note 4
# 8          Redmi Note 4
# 9             vivo Y51L
# 10         Redmi Note 3
# 11             SM-A500G
# 12            vivo 1610
# 13             SM-G610F
# 14         Redmi Note 4
# 15             Redmi 3S
# 16            vivo 1610
# 17      Lenovo A7020a48
# 18             Redmi 3S
# 19             SM-J700F
# 20             SM-G570F
# 21             Redmi 3S
# 22             SM-J110H
# 23            vivo 1610
# 24                A1601
# 25         Redmi Note 4
# 26           Moto G (4)
# 27                Mi 4i
# 28             TECNO i3
# 29        Lenovo K50a40
#              ...
# 9963               C103
# 9964          vivo 1606
# 9965             YU5530
# 9966           SM-J200G
# 9967       Redmi Note 4
# 9968           SM-J200G
# ...

# %%
hour1 = plot_df.hour

# %%
hour1.plot(kind = 'hist')

# %%
scaty = plot_df.loc[:,['user_id','mobile_brand_name']]

# %%
bz = plot_df.groupby('mobile_brand_name')

# %%
#bz.count()['user_id']

# %%
bz.mobile_brand_name

# %%
#bz.plot.scatter(kind = 'scatter')

# %%
plot_df.plot?

# %%
#scaty.plot.scatter('mobile_brand_name', 'user_id')

# %%
s = scaty.iloc[1:10,]

# %%
a['user_id' == '59d23b4cb2cb0511457c3718']
# Out:
# '59d23b4cb2cb0511457c3718'

# %%
a['mobile_brand_name' == 'Vivo']
# Out:
# '59d23b4cb2cb0511457c3718'

# %%
t = plot_df.iloc[0:10,0:3]

# %%
t
# Out:
#                     user_id mobile_brand_name   device_model
# 0  59742df346ab8ae80d7320e5           Samsung       SM-J200G
# 1  59d23b4cb2cb0511457c3718            Xiaomi       Redmi 4A
# 2  59c8671a625fbbd425d735ae           Samsung  Swipe_Elite_3
# 3  591ff88228d8f8c86bfd75bf              OPPO           A37f
# 4  59feaccfa3c446c82ca3e68c              Sony          C6902
# 5  59f13874bb299b692aeef502           Samsung       SM-J700F
# 6  59d4f647bb299b692add0d24          Motorola      OctaOne_5
# 7  59d8bafdfc67610b4500232b            Xiaomi   Redmi Note 4
# 8  59cc674efc67610b45f1c83b            Xiaomi   Redmi Note 4
# 9  58b072b134182301374ff77d              Vivo      vivo Y51L

# %%
pd.crosstab(t.mobile_brand_name,t.user_id,aggfunc = )
# Out:
# user_id            58b072b134182301374ff77d  591ff88228d8f8c86bfd75bf  \
# mobile_brand_name
# Motorola                                  0                         0
# OPPO                                      0                         1
# Samsung                                   0                         0
# Sony                                      0                         0
# Vivo                                      1                         0
# Xiaomi                                    0                         0
#
# user_id            59742df346ab8ae80d7320e5  59c8671a625fbbd425d735ae  \
# mobile_brand_name
# Motorola                                  0                         0
# OPPO                                      0                         0
# Samsung                                   1                         1
# Sony                                      0                         0
# Vivo                                      0                         0
# ...

# %%
group_by_brand = plot_df.groupby('mobile_brand_name')

# %%
#group_by_brand.count().user_id

# %%
group_by_model_sub_model = plot_df.groupby(['mobile_brand_name','device_model'])

# %%
group_by_model_sub_model.agg(['count'])
# Out:
#                                               user_id time_stamp  year month  \
#                                                 count      count count count
# mobile_brand_name device_model
# Acer              A210                              1          1     1     1
#                   T02                               4          4     4     4
# Alcatel           5010U                             1          1     1     1
#                   5045T                             1          1     1     1
#                   5056E                             1          1     1     1
#                   6042D                             1          1     1     1
#                   8050D                             1          1     1     1
#                   9002X                             1          1     1     1
#                   9003X                             1          1     1     1
#                   LS-5021                           2          2     2     2
# ...

# %%
group_by_model_sub_model.plot.scatter(x = group_by_model_sub_model.user_id.value_counts() , y = group_by_model_sub_model.device_model.agg("count")  )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-120-04dec625ce83> in <module>()
# ----> 1 group_by_model_sub_model.plot.scatter(x = group_by_model_sub_model.user_id.value_counts() , y = group_by_model_sub_model.device_model.agg("count")  )
#
# /home/shaswat/anaconda3/lib/python3.5/site-packages/pandas/core/groupby.py in attr(*args, **kwargs)
#     353             def f(self):
#     354                 return getattr(self.plot, name)(*args, **kwargs)
# --> 355             return self._groupby.apply(f)
#     356         return attr
#     357
#
# /home/shaswat/anaconda3/lib/python3.5/site-packages/pandas/core/groupby.py in apply(self, func, *args, **kwargs)
#     719         # ignore SettingWithCopy here in case the user mutates
#     720         with option_context('mode.chained_assignment', None):
# --> 721             return self._python_apply_general(f)
# ...

# %%
group_by_brand.index.values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-125-c9dc3cf6ffb4> in <module>()
# ----> 1 group_by_brand.index.values()
#
# /home/shaswat/anaconda3/lib/python3.5/site-packages/pandas/core/groupby.py in __getattr__(self, attr)
#     547             return self[attr]
#     548         if hasattr(self.obj, attr):
# --> 549             return self._make_wrapper(attr)
#     550
#     551         raise AttributeError("%r object has no attribute %r" %
#
# /home/shaswat/anaconda3/lib/python3.5/site-packages/pandas/core/groupby.py in _make_wrapper(self, name)
#     561                    "using the 'apply' method".format(kind, name,
#     562                                                      type(self).__name__))
# --> 563             raise AttributeError(msg)
#     564
#     565         # need to setup the selection
#
# ...
